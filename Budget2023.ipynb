# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data = pd.read_excel("spreadsheet.xlsx")
data.head()
import warnings 
warnings.filterwarnings("ignore")

# %%
data
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data.dropna()
# Out:
#                                  Department /Ministry  \
# 0                             MINISTRY OF AGRICULTURE
# 1                         DEPARTMENT OF ATOMIC ENERGY
# 2                          MINISTRY OF AYURVEDA, YOGA
# 3                MINISTRY OF CHEMICALS AND FERTILISER
# 4                          MINISTRY OF CIVIL AVIATION
# 5                                    MINISTRY OF COAL
# 6                   MINISTRY OF COMMERCE AND INDUSTRY
# 7                           MINISTRY OF COMMUNICATION
# 8                        MINISTRY OF CONSUMER AFFAIRS
# 9                       MINISTRY OF CORPORATE AFFAIRS
# 10                                MINISTRY OF CULTURE
# 11                                MINISTRY OF DEFENCE
# 12    MINISTRY OF DEVELOPMENT OF NORTH EASTERN REGION
# 13                         MINISTRY OF EARTH SCIENCES
# 14                              MINISTRY OF EDUCATION
# 15  MINISTRY OF ELECTRONICS AND INFORMATION TECHNO...
# ...

# %%
data = data.iloc[[0,3,7,8,11,14,18,21,23,24,26,41,42,43],:]
row = {'Department /Ministry': 'OTHERS', 'Fund allotted(in ₹crores)': 343699.8300000001}
data = data.append(row, ignore_index = True)
print(data)
# Out:
#                       Department /Ministry  Fund allotted(in ₹crores)
# 0                  MINISTRY OF AGRICULTURE                  125035.79
# 1     MINISTRY OF CHEMICALS AND FERTILISER                  178481.99
# 2                MINISTRY OF COMMUNICATION                  123393.05
# 3             MINISTRY OF CONSUMER AFFAIRS                  205764.60
# 4                      MINISTRY OF DEFENCE                  593537.64
# 5                    MINISTRY OF EDUCATION                  112899.47
# 6                      MINISTRY OF FINANCE                 1689719.17
# 7    MINISTRY OF HEALTH AND FAMILY WELFARE                   89155.00
# 8                 MINISTRY OF HOME AFFAIRS                  196034.94
# 9    MINISTRY OF HOUSING AND URBAN AFFAIRS                   76431.60
# 10                  MINISTRY OF JAL SHAKTI                   97277.67
# 11                    MINISTRY OF RAILWAYS                  241267.51
# ...

# %%
data.plot.bar(x='Department /Ministry', y='Fund allotted(in ₹crores)')
# Out:
# <AxesSubplot:xlabel='Department /Ministry'>

# %%
df = data["Fund allotted(in ₹crores)"]
labels = data["Department /Ministry"]
plt.figure(figsize=(7,7))
plt.pie(df, labels=labels, autopct='%1.1f%%', startangle=90, pctdistance=0.85, shadow =True)
central_circle = plt.Circle((0, 0), 0.5, color='white')
fig = plt.gcf()
fig.gca().add_artist(central_circle)
plt.rc('font', size=12)
plt.title("Distribution of The Budget", fontsize=20)
plt.show()
